# %%
import os
import numpy as np
import urllib
import random
dat = np.loadtxt(fname = "zscore.txt") # no commas, no
dat.shape


######################################## Draft 1
#################### Get the interactions between a gene to all others (29) FOR all 30 genes
#all_inters=[] # Each gene's interaction with all other 29 genes: multidimensional array with 30 sublists in a single list
#rand= [-1,1]
#for column in dat.T:
    #inters=[] # A single gene's interaction with all other 29 genes: single list that gets appended to all_inters
    #i= random.choice(rand)
    #for cell in column:
        #j=random.choice(rand)
        #inter=cell*j # a single gene-gene interaction
        #inters+=[inter]
    #all_inters+=[inters]
#################### For a gene and it's interaction with the other 29 genes, calculate E
#E=[] # energy value calculation for all 30 genes: single list with 30 entries
#for item in all_inters:
    #s=sum(item)*i
    #E+=[s]
######################################## Draft 2
#################### Produce a random list made up of -1 or +1 
while E_change > E :
    random.seed(54738654398)
    rand_30=[]
    ones=[-1,1]
    for i in range(len(dat)):
        number=random.choice(ones)
        rand_30+=[number]
    #################### Get the interactions between a gene to all others (29) FOR all 30 genes, finally calculate E
    #all_inters=[] # not required, though method works

    E_all=[]
    for colnum in range(len(dat)):
        inters=[] 
        for rownum in range(len(dat)):
            inter=dat.T[rownum,colnum]*random.choice(ones) 
            inters+=[inter]
    #################### For a gene and it's interaction with the other 29 genes, calculate E 
        E=sum(inters)*rand_30[colnum]
        E_all+=[E]
        #all_inters+=[inters] # not required, though method works
    #################### TRICKY
        #new_Es=[]
        c=0
        for E_index in range(len(E_all)):
            if E_all[E_index] < 0:
                E_change=sum(inters)*-1*rand_30[colnum]
                #new_Es+=[E_change]
                count+=1
    print(c)
            #else:
                #new_Es+=E_all[E_index]
                
        

        
#################### Create a dictionary of all E values that were < 0
initial_negs={}
for e in range(len(E_all)):
    if E_all[e] < 0:
        initial_negs[e]=E_all[e]
#print(initial_negs)















######################################## Draft 3
#################### Produce a random list made up of -1 or +1 
#random.seed(54738654398)
#rand_30=[]
#ones=[-1,1]
#for i in range(len(dat)):
    #one=random.choice(ones)
    #rand_30+=[one]
#################### Get the interactions between a gene to all others (29) FOR all 30 genes
#while E_initial 
    #E_initial=[]
    #for colnum in range(len(dat)):
        #inters=[] 
        #for rownum in range(len(dat)):
            #inter=dat.T[rownum,colnum]*random.choice(ones) 
            #inters+=[inter]
            #e=sum(inters)*rand_30[colnum]
        #E_initial+=[e]
            #if e < 0:
                #e=sum(inters)*-1*rand_30[colnum]
    #print(E_initial)

#################### Create a dictionary of all E values that were < 0
#################### Modify E if necessary!
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-9391c27c3c3f> in <module>()
#      26 ######################################## Draft 2
#      27 #################### Produce a random list made up of -1 or +1
# ---> 28 while E_change > E :
#      29     random.seed(54738654398)
#      30     rand_30=[]
#
# NameError: name 'E_change' is not defined
